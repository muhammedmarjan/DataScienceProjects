# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('space.csv')

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# 0  54922      491
# 1  51615      541
# 2  52023      513
# 3  54922      510
# 4  54922      512

# %%
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 0     15.50342  15.22531   752    301       4    267  3.722360e+18    STAR
# 1     16.48922  16.39150   752    301       4    267  3.638140e+17    STAR
# 2     17.08732  16.80125   752    301       4    268  3.232740e+17  GALAXY
# 3     15.98233  15.90438   752    301       4    269  3.722370e+18    STAR
# 4     16.55492  16.61326   752    301       4    269  3.722370e+18    STAR
# ...        ...       ...   ...    ...     ...    ...           ...     ...
# 9995  16.68305  16.50570  1345    301       3    161  5.033450e+17  GALAXY
# 9996  16.71661  16.69897  1345    301       3    162  5.033400e+17  GALAXY
# 9997  17.43302  17.42048  1345    301       3    162  8.222620e+18    STAR
# 9998  17.36284  17.13988  1345    301       3    163  5.033400e+17  GALAXY
# 9999  15.83548  15.50588  1345    301       3    163  5.033410e+17  GALAXY
#
#       redshift  plate    mjd  fiberid
# 0    -0.000009   3306  54922      491
# 1    -0.000055    323  51615      541
# 2     0.123111    287  52023      513
# 3    -0.000111   3306  54922      510
# 4     0.000590   3306  54922      512
# ...        ...    ...    ...      ...
# 9995  0.027583    447  51877      246
# 9996  0.117772    447  51877      228
# 9997 -0.000402   7303  57013      622
# 9998  0.014019    447  51877      229
# 9999  0.118417    447  51877      233
#
# [10000 rows x 18 columns]

# %%
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %% [markdown]
# data does not contain any null values

# %%
for i in df:
      print("column_name = ",i)
      print(df[i].value_counts())
      print("\n")
# Out:
# column_name =  objid
# 1.237650e+18    10000
# Name: objid, dtype: int64
#
#
# column_name =  ra
# 226.511352    1
# 186.864198    1
# 162.412783    1
# 242.416598    1
# 25.765495     1
#              ..
# 218.427367    1
# 179.365032    1
# 187.113033    1
# 235.913493    1
# 182.372733    1
# Name: ra, Length: 10000, dtype: int64
#
#
# column_name =  dec
#  0.701145     1
#  0.031148     1
#  0.322301     1
# -0.728211     1
#  60.960316    1
#              ..
# -0.048648     1
#  0.321775     1
# -3.512726     1
#  57.641016    1
#  0.661888     1
# Name: dec, Length: 10000, dtype: int64
#
#
# column_name =  u
# 18.90212    3
# 18.99697    3
# 18.98400    3
# 19.53507    3
# 19.56350    3
#            ..
# 19.27596    1
# 19.51822    1
# 18.23952    1
# 18.47838    1
# 18.77445    1
# Name: u, Length: 9730, dtype: int64
#
#
# column_name =  g
# 17.55623    3
# 17.75478    3
# 17.60766    3
# 18.31910    3
# 17.53612    2
#            ..
# 16.79101    1
# 18.01411    1
# 16.93613    1
# 17.68695    1
# 17.87934    1
# Name: g, Length: 9817, dtype: int64
#
#
# column_name =  r
# 15.99986    3
# 16.48978    3
# 16.70929    2
# 17.21182    2
# 16.27899    2
#            ..
# 19.18255    1
# 16.03177    1
# 16.27091    1
# 17.45321    1
# 17.05181    1
# Name: r, Length: 9852, dtype: int64
#
#
# column_name =  i
# 18.77594    2
# 16.70494    2
# 16.91346    2
# 15.61870    2
# 17.19571    2
#            ..
# 15.41105    1
# 16.61259    1
# 16.52959    1
# 15.61332    1
# 17.93967    1
# Name: i, Length: 9890, dtype: int64
#
#
# column_name =  z
# 17.18764    2
# 17.15916    2
# 16.57886    2
# 17.30935    2
# 16.42915    2
#            ..
# 16.58965    1
# 13.45055    1
# 16.96533    1
# 17.53121    1
# 17.83702    1
# Name: z, Length: 9896, dtype: int64
#
#
# column_name =  run
# 756     3060
# 752     2086
# 1345     915
# 1350     540
# 1140     527
# 745      453
# 1035     396
# 1412     347
# 1302     246
# 1331     245
# 1231     245
# 1334     212
# 1239     197
# 1336     182
# 1404     137
# 1045     112
# 1402      49
# 308       31
# 1411      10
# 1356       4
# 727        4
# 1119       1
# 1332       1
# Name: run, dtype: int64
#
#
# column_name =  rerun
# 301    10000
# Name: rerun, dtype: int64
#
#
# column_name =  camcol
# 4    1834
# 5    1827
# 6    1769
# 2    1712
# 3    1560
# 1    1298
# Name: camcol, dtype: int64
#
#
# column_name =  field
# 301    62
# 302    58
# 304    56
# 305    55
# 309    54
#        ..
# 499     1
# 676     1
# 507     1
# 660     1
# 503     1
# Name: field, Length: 703, dtype: int64
#
#
# column_name =  specobjid
# 2.881270e+18    18
# 2.881220e+18    18
# 3.722230e+18    18
# 3.222410e+18    17
# 2.880120e+18    17
#                 ..
# 3.885350e+17     1
# 4.841730e+17     1
# 4.988460e+17     1
# 4.315780e+18     1
# 3.716180e+17     1
# Name: specobjid, Length: 6349, dtype: int64
#
#
# column_name =  class
# GALAXY    4998
# STAR      4152
# QSO        850
# Name: class, dtype: int64
#
#
# column_name =  redshift
#  0.000000    19
# -0.000020     6
# -0.000062     5
# -0.000010     4
# -0.000033     4
#              ..
#  0.060941     1
#  1.269727     1
#  1.912334     1
# -0.000522     1
# -0.000424     1
# Name: redshift, Length: 9637, dtype: int64
#
#
# column_name =  plate
# 2558    222
# 2559    221
# 2895    166
# 276     156
# 7456    139
#        ...
# 7319      1
# 2952      1
# 7090      1
# 7562      1
# 1635      1
# Name: plate, Length: 487, dtype: int64
#
#
# column_name =  mjd
# 52000    312
# 54140    222
# 51909    222
# 54208    221
# 51908    214
#         ...
# 53299      1
# 55618      1
# 56991      1
# 51696      1
# 53053      1
# Name: mjd, Length: 355, dtype: int64
#
#
# column_name =  fiberid
# 155    29
# 138    28
# 454    27
# 249    26
# 11     26
#        ..
# 866     1
# 858     1
# 850     1
# 842     1
# 915     1
# Name: fiberid, Length: 892, dtype: int64

# %%
df=df.drop(['objid','rerun'],axis=1)

# %%
df.head()
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
#
#    run  camcol  field     specobjid   class  redshift  plate    mjd  fiberid
# 0  752       4    267  3.722360e+18    STAR -0.000009   3306  54922      491
# 1  752       4    267  3.638140e+17    STAR -0.000055    323  51615      541
# 2  752       4    268  3.232740e+17  GALAXY  0.123111    287  52023      513
# 3  752       4    269  3.722370e+18    STAR -0.000111   3306  54922      510
# 4  752       4    269  3.722370e+18    STAR  0.000590   3306  54922      512

# %%
df.describe()
# Out:
#                  ra           dec             u             g             r  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     175.529987     14.836148     18.619355     17.371931     16.840963
# std       47.783439     25.212207      0.828656      0.945457      1.067764
# min        8.235100     -5.382632     12.988970     12.799550     12.431600
# 25%      157.370946     -0.539035     18.178035     16.815100     16.173333
# 50%      180.394514      0.404166     18.853095     17.495135     16.858770
# 75%      201.547279     35.649397     19.259232     18.010145     17.512675
# max      260.884382     68.542265     19.599900     19.918970     24.802040
#
#                   i             z           run        camcol         field  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      16.583579     16.422833    981.034800      3.648700    302.380100
# std        1.141805      1.203188    273.305024      1.666183    162.577763
# min       11.947210     11.610410    308.000000      1.000000     11.000000
# 25%       15.853705     15.618285    752.000000      2.000000    184.000000
# 50%       16.554985     16.389945    756.000000      4.000000    299.000000
# 75%       17.258550     17.141447   1331.000000      5.000000    414.000000
# max       28.179630     22.833060   1412.000000      6.000000    768.000000
#
#           specobjid      redshift         plate           mjd       fiberid
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.645022e+18      0.143726   1460.986400  52943.533300    353.069400
# std    2.013998e+18      0.388774   1788.778371   1511.150651    206.298149
# min    2.995780e+17     -0.004136    266.000000  51578.000000      1.000000
# 25%    3.389248e+17      0.000081    301.000000  51900.000000    186.750000
# 50%    4.966580e+17      0.042591    441.000000  51997.000000    351.000000
# 75%    2.881300e+18      0.092579   2559.000000  54468.000000    510.000000
# max    9.468830e+18      5.353854   8410.000000  57481.000000   1000.000000

# %% [markdown]
# * there is a high difference between the 75% and max value in ra,dec, field,specobjid,redshift,plate,fiberid so outliers may present

# %%
sns.heatmap(df.isnull())

# %%
df.hist(figsize=(13,13))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC7835EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC835D948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8396408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC83D0548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8409648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8441708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC847B848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC89A4988>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC89AF548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC89E7708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8A4DC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8A86D08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8ABEE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8AF7F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8B35088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DCC8B6D148>]],
#       dtype=object)

# %%
sns.countplot(df['class'])

# %%
df.columns
# Out:
# Index(['ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'camcol', 'field',
#        'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
df=pd.DataFrame(data=df)

# %%
df_ob=df[['ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'camcol', 'field',
       'specobjid', 'redshift', 'plate', 'mjd', 'fiberid']]

# %%
for i in df_ob:
    plt.figure(figsize=(10,30))
    plt.subplot(311)
    sns.distplot(df_ob[i])

# %%
for i in df_ob:
    plt.figure(figsize=(10,50))
    plt.subplot(911)
    sns.boxplot(df_ob[i],orient='v')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['class']=le.fit_transform(df['class'])

# %%
df.head()
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
#
#    run  camcol  field     specobjid  class  redshift  plate    mjd  fiberid
# 0  752       4    267  3.722360e+18      2 -0.000009   3306  54922      491
# 1  752       4    267  3.638140e+17      2 -0.000055    323  51615      541
# 2  752       4    268  3.232740e+17      0  0.123111    287  52023      513
# 3  752       4    269  3.722370e+18      2 -0.000111   3306  54922      510
# 4  752       4    269  3.722370e+18      2  0.000590   3306  54922      512

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
df_n=df[(z<3).all(axis=1)]

# %%
df_n.shape
# Out:
# (8698, 16)

# %%
df.shape
# Out:
# (10000, 16)

# %%
df=df_n
df.shape
# Out:
# (8698, 16)

# %%
x=df.drop(['class'],axis=1)
x.head()
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
#
#    run  camcol  field     specobjid  redshift  plate    mjd  fiberid
# 0  752       4    267  3.722360e+18 -0.000009   3306  54922      491
# 1  752       4    267  3.638140e+17 -0.000055    323  51615      541
# 2  752       4    268  3.232740e+17  0.123111    287  52023      513
# 3  752       4    269  3.722370e+18 -0.000111   3306  54922      510
# 4  752       4    269  3.722370e+18  0.000590   3306  54922      512

# %%
y=df['class']
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    2
# Name: class, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=63)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.svm import SVC

# %%
KNR=KNeighborsClassifier()
DTR=DecisionTreeClassifier(random_state=63)
ABR=AdaBoostClassifier(random_state=63)
RFR=RandomForestClassifier(random_state=63)
GBR=GradientBoostingClassifier(random_state=63)
SV=SVC(random_state=63)

# %%
models=[]
models.append(('DecisionTreeClassifier',DTR))
models.append(('KNeighborsClassifier',KNR))
models.append(('AdaBoostClassifier',ABR))
models.append(('RandomForestClassifier',RFR))
models.append(('GradientBoostingClassifier',GBR))
models.append(('SVC', SV))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
Model=[]
score = []
cvs=[]
MSE=[]
for name,model in models:
    print('*********************************',name,'*********************************')
    print('\n',model)
    Model.append(name)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score = ',AS)
    score.append(AS*100)
    print('\n')
    sc = cross_val_score(model, x, y, cv=10, scoring='accuracy').mean()
    print('Cross_Val_Score = ',sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
# Out:
# ********************************* DecisionTreeClassifier *********************************
#
#  DecisionTreeClassifier(random_state=63)
#
#
# Accuracy_score =  0.982183908045977
#
#
# Cross_Val_Score =  0.98333015885613
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       935
#            1       0.87      0.85      0.86        87
#            2       1.00      0.99      1.00       718
#
#     accuracy                           0.98      1740
#    macro avg       0.95      0.94      0.95      1740
# weighted avg       0.98      0.98      0.98      1740
#
#
#
# [[923  11   1]
#  [ 13  74   0]
#  [  6   0 712]]
#
#
# ********************************* KNeighborsClassifier *********************************
#
#  KNeighborsClassifier()
#
#
# Accuracy_score =  0.914367816091954
#
#
# Cross_Val_Score =  0.9056130047749427
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92       935
#            1       0.96      0.79      0.87        87
#            2       0.94      0.87      0.91       718
#
#     accuracy                           0.91      1740
#    macro avg       0.93      0.87      0.90      1740
# weighted avg       0.92      0.91      0.91      1740
#
#
#
# [[895   3  37]
#  [ 16  69   2]
#  [ 91   0 627]]
#
#
# ********************************* AdaBoostClassifier *********************************
#
#  AdaBoostClassifier(random_state=63)
#
#
# Accuracy_score =  0.7793103448275862
#
#
# Cross_Val_Score =  0.8600605796066294
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.69      0.77       935
#            1       0.21      0.91      0.35        87
#            2       1.00      0.88      0.94       718
#
#     accuracy                           0.78      1740
#    macro avg       0.70      0.83      0.68      1740
# weighted avg       0.89      0.78      0.82      1740
#
#
#
# [[642 290   3]
#  [  8  79   0]
#  [ 83   0 635]]
#
#
# ********************************* RandomForestClassifier *********************************
#
#  RandomForestClassifier(random_state=63)
#
#
# Accuracy_score =  0.9867816091954023
#
#
# Cross_Val_Score =  0.9879285213549727
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       935
#            1       0.94      0.84      0.88        87
#            2       0.99      1.00      1.00       718
#
#     accuracy                           0.99      1740
#    macro avg       0.97      0.94      0.96      1740
# weighted avg       0.99      0.99      0.99      1740
#
#
#
# [[926   5   4]
#  [ 14  73   0]
#  [  0   0 718]]
#
#
# ********************************* GradientBoostingClassifier *********************************
#
#  GradientBoostingClassifier(random_state=63)
#
#
# Accuracy_score =  0.9873563218390805
#
#
# Cross_Val_Score =  0.9887331190561222
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       935
#            1       0.91      0.85      0.88        87
#            2       1.00      1.00      1.00       718
#
#     accuracy                           0.99      1740
#    macro avg       0.97      0.95      0.96      1740
# weighted avg       0.99      0.99      0.99      1740
#
#
#
# [[929   5   1]
#  [ 13  74   0]
#  [  1   2 715]]
#
#
# ********************************* SVC *********************************
#
#  SVC(random_state=63)
#
#
# Accuracy_score =  0.9683908045977011
#
#
# Cross_Val_Score =  0.9698789730566247
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       935
#            1       0.95      0.83      0.88        87
#            2       0.96      0.99      0.98       718
#
#     accuracy                           0.97      1740
#    macro avg       0.96      0.93      0.94      1740
# weighted avg       0.97      0.97      0.97      1740
#
#
#
# [[902   4  29]
#  [ 15  72   0]
#  [  7   0 711]]

# %%
result = pd.DataFrame({'Model': Model, 'Accuracy_score': score ,'Cross_val_score':cvs})
result
# Out:
#                         Model  Accuracy_score  Cross_val_score
# 0      DecisionTreeClassifier       98.218391        98.333016
# 1        KNeighborsClassifier       91.436782        90.561300
# 2          AdaBoostClassifier       77.931034        86.006058
# 3      RandomForestClassifier       98.678161        98.792852
# 4  GradientBoostingClassifier       98.735632        98.873312
# 5                         SVC       96.839080        96.987897

# %% [markdown]
# Gradient boosting classifier is performing better

# %%
from sklearn import externals
import joblib
joblib.dump(GBR,'spaceserver.pkl')
# Out:
# ['spaceserver.pkl']
